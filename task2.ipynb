# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
# id column graph completely looks different from other columns

# %%
df=df.drop('Id',axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
# if we compare these 4 graphs petal length graph is deviating a lot compared to other graphs.

# %%
df.plot(kind='line')
# line plot
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
# we are not understanding anything clearly from this bar graph.

# %%
df[5:11]
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5             5.4           3.9            1.7           0.4  Iris-setosa
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.4            1.5           0.2  Iris-setosa
# 8             4.4           2.9            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa

# %%
df[5:11].plot(kind="bar",figsize=(20,10))
# Out:
# <Axes: >

# %%
# in the bar-plot the species column is not mentioned because it is categorical type of data.

# %%
# Let consider i want to plot only one specific rows using bar plot

# %%
df.iloc[[5]].plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
# this is vertical bar plot.

# %%
df.iloc[[5]].plot(kind='barh',figsize=(20,10))
# Out:
# <Axes: >

# %%
# this is horizontal bar plot.

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# this is histogram
# histogram tells the range and frequency of data values in the particular range.
# in x-axis of histogram we will see range of data values present in the dataset.
# in y-axis of histogram we will see the frequency of values of the data in between particular range.

# %%
df['SepalLengthCm'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['SepalLengthCm'].plot(kind="hist",orientation='horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='r')
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.hist(figsize=(20,10),color='g',alpha=.2)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
df.plot(kind='box',figsize=(20,10))
# Out:
# <Axes: >

# %%
# If we observe the PetalLengthCm boxplot we can say that majority of the data is in between 25% and 50% .
# But if we see the SepalLengthCm column the data is equally distributed among all the quartiles .

# %%
# in the box plot of sepalWidthCm column we can see circles near to maximum and minimum points those are outliers.
# there are 3 data values more than maximum value which is outlier
# there is one data value less than minimum value which is outlier
# when we are learning machine learning at that time we need to find outliers in the dataset .At that times these graphs are
# helpful.

# outliers are nothing but it is a kind of dataset which is not able to fit itself in between the regular distribution of 
# the dataset.

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
'''
# IQR is 75%-25% 
# using this we can find IQR for each column
# let consider i want to do calculations for SepalLengthCm column
IQR= 6.400000 - 5.100000 = 1.3
Based on the data we can calculate maximum value also which is 75% + 1.5 * (IQR)= 6.4 + 1.5*1.3=8.35 
In SepalLengthCm column if u see the max value which is 7.9 . 
while calculating we got approximate value which is 8.35

Based on the data we can calculate the minimum value which is 25% - 1.5 * (IQR)= 5.1- 1.5*1.3 = 3.15
In SepalLengthCm column if u see the min value which is 4.3
while calculating we got approximate value which is 3.15
    
the values we get when we apply describe function is approximate values.Not exact values.
'''

# %%
df.plot(kind='box',figsize=(20,10),color='r')
# Out:
# <Axes: >

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'})
# Out:
# <Axes: >

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'g','whiskers':'r'},vert=False)
# this is box plot horizontal.
# Out:
# <Axes: >

# %%
df.plot(kind='area',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.plot(kind='area',figsize=(20,10),alpha=.4)
# Out:
# <Axes: >

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# Let consider i want to know the relationship between SepalLengthCm and SepalWidthCm
# how these SepalLengthCm,SepalWidthCm are behaving with each other
# i want to know how SepalLengthCm is increasing wrt to SepalWidthCm
# in these type of cases we can use scatter plot.
# scatter plot is 2-D graph.
# we can set own x and y-axis in scatter plot.

# %%
df.plot.scatter(x='SepalLengthCm',y='SepalWidthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm')
# here we are trying to represent colour with SepalWidthCm column data value.
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',s=600)
'''
if i want to increase the size of the dot then we use 's' parameter.
s means size.
we can change the dot size in this way.
if we want big dots then we can give the big value of the 's'.
if we want small dots then we can give the small value of the 's' .

'''
# Out:
# "\nif i want to increase the size of the dot then we use 's' parameter.\ns means size.\nwe can change the dot size in this way.\nif we want big dots then we can give the big value of the 's'.\nif we want small dots then we can give the small value of the 's' .\n\n"

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm',c='SepalWidthCm',s=100)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x = 'SepalLengthCm' , y = 'PetalLengthCm',c = 'SepalWidthCm',s = df['PetalWidthCm']*500)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x = 'SepalLengthCm' , y = 'PetalLengthCm' , gridsize= 10 ,C ='SepalWidthCm' )
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df1=df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <Axes: ylabel='0'>

# %%
df1
# Out:
# SepalLengthCm    5.1
# SepalWidthCm     3.5
# PetalLengthCm    1.4
# PetalWidthCm     0.2
# Name: 0, dtype: float64

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=df.sepal_length,y=df.petal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
plt.plot(df.sepal_length,df.petal_length)
plt.xlabel('sepal_length')
plt.ylabel('petal_length')
# Out:
# Text(0, 0.5, 'petal_length')

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_11636\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df)

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,hue='petal_width')

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,style='petal_width')

# %%
sns.relplot(x='sepal_length',y='sepal_width',data=df,kind='line')
